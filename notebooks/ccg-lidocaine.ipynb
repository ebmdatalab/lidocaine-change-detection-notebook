# %%
# NBVAL_IGNORE_OUTPUT
# ^this is a magic comment to work around this issue https://github.com/ebmdatalab/custom-docker/issues/10
from change_detection import functions as chg
from lib.outliers import *  #This is copied into the local folder from a branch ebmdatalab pandas library - it will be placed in its own repo to install at a later dat
# Out:
# /home/app/notebook/lib/outliers.py:11: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
# NBVAL_IGNORE_OUTPUT
# ^this is a magic comment to work around this issue https://github.com/ebmdatalab/custom-docker/issues/10
lidocaine_class = chg.ChangeDetection('ccg_data_lplido%',
                                    measure=True,
                                    direction='down',
                                    use_cache=True,
                                    overwrite=False,
                                    verbose=False,
                                    draw_figures='no')
lidocaine_class.run()

# %%
lidocaine = lidocaine_class.concatenate_outputs()
lidocaine.head()
# Out:
#                            is.nbreak  is.tfirst  is.tfirst.pknown  \
# measure              name
# ccg_data_lplidocaine 00C   2          20.0       20.0
#                      00D   5          14.0       14.0
#                      00J   2          17.0       17.0
#                      00K   2          19.0       19.0
#                      00L   6          16.0       16.0
#
#                            is.tfirst.pknown.offs  is.tfirst.offs  \
# measure              name
# ccg_data_lplidocaine 00C   20.0                   20.0
#                      00D   17.0                   17.0
#                      00J   17.0                   17.0
#                      00K   19.0                   19.0
#                      00L   28.0                   28.0
#
#                            is.tfirst.big  is.slope.ma  is.slope.ma.prop  \
# measure              name
# ccg_data_lplidocaine 00C   20.0          -1.201541    -0.009604
#                      00D   17.0          -9.760594    -0.099652
#                      00J   17.0          -5.927963    -0.056012
#                      00K   19.0          -0.133067    -0.003073
#                      00L   34.0          -0.997343    -0.037921
#
#                            is.slope.ma.prop.lev  is.intlev.initlev  \
# measure              name
# ccg_data_lplidocaine 00C   0.512195              126.315378
#                      00D   0.623492              104.553810
#                      00J   0.547592              111.761149
#                      00K   0.523810              43.440774
#                      00L   0.558819              28.008975
#
#                            is.intlev.finallev  is.intlev.levd  \
# measure              name
# ccg_data_lplidocaine 00C   77.052210           49.263168
#                      00D   26.280213           78.273598
#                      00J   46.808102           64.953048
#                      00K   37.851952           5.588822
#                      00L   11.946381           16.062593
#
#                            is.intlev.levdprop
# measure              name
# ccg_data_lplidocaine 00C   0.390001
#                      00D   0.748644
#                      00J   0.581177
#                      00K   0.128654
#                      00L   0.573480

# %%
filtered_sparkline(lidocaine,
                  'ccg_data_lplido/ccg_data_lplido',
                  'ccg_data_lplidocaine')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-39d47e2d8075> in <module>
# ----> 1 filtered_sparkline(lidocaine,
#       2                   'ccg_data_lplido/ccg_data_lplido',
#       3                   'ccg_data_lplidocaine')
#
# /home/app/notebook/lib/outliers.py in filtered_sparkline(df, name, measure)
#     151
#     152 def filtered_sparkline(df, name, measure):
# --> 153     data = pd.read_csv('data/{}/bq_cache.csv'.format(name),index_col='code')
#     154     data['month'] = pd.to_datetime(data['month'])
#     155     data['rate'] = data['numerator'] / data['denominator']
#
# ~/.pyenv/versions/3.8.1/lib/python3.8/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/.pyenv/versions/3.8.1/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~/.pyenv/versions/3.8.1/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~/.pyenv/versions/3.8.1/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~/.pyenv/versions/3.8.1/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File data/ccg_data_lplido/ccg_data_lplido/bq_cache.csv does not exist: 'data/ccg_data_lplido/ccg_data_lplido/bq_cache.csv'
